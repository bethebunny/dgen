# %%
# %load_ext dgen.notebook

# %%
# %%dgen-dialect mytest
# from builtin import Index, Nil
# op add(lhs: Index, rhs: Index) -> Index
# op constant<value: Index>() -> Index

# %%
# Accessing the ops raises AttributeError if the magic failed to define them.
print(mytest.AddOp)
print(mytest.ConstantOp)
