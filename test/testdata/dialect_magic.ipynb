# %%
# %load_ext dgen.notebook

# %%
# %%dgen-dialect mytest
# from builtin import Index, Nil
# op add(lhs: Index, rhs: Index) -> Index
# op constant<value: Index>() -> Index

# %%
assert hasattr(mytest, 'AddOp'), 'AddOp not found in dialect'
assert hasattr(mytest, 'ConstantOp'), 'ConstantOp not found in dialect'
from dgen import Dialect
assert 'mytest' in Dialect._registry, 'mytest not in Dialect._registry'
